# %%
# !pip install tweepy==4.12.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 KB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 7.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# ...

# %%
import tweepy

# %%
tweepy.__version__
# Out:
# '4.12.1'

# %%
# Authenticate with your Twitter API keys and access tokens
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAD5azgAAAAAAuG8CxzVp42RacKxMVN4%2FZ1hbQn4%3DK5RR8FfXnVTyVU7vGJVMZLyD20ZarLKnkv6Lk5bsGztvWqP7Lg'

# Create a Tweepy API object
auth = tweepy.auth.OAuth2BearerHandler(bearer_token)
api = tweepy.API(auth)

# %%
# Define the search query and the search period
query = "#diet"
start_date = "2022-12-01"
end_date = "2022-12-01"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
diet_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    diet_tweets.append(tweet)

# %%
len(diet_tweets)
# Out:
# 3850

# %%
# Define the search query and the search period
query = "#caloriedeficit"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
caloriedeficit_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    caloriedeficit_tweets.append(tweet)

# %%
len(caloriedeficit_tweets)
# Out:
# 87

# %%
# Define the search query and the search period
query = "#workout"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
workout_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    workout_tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-23-9fca572f030c> in <module>
#       5 workout_tweets = []
#       6 #for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
# ----> 7 for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
#       8     workout_tweets.append(tweet)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
len(workout_tweets)
# Out:
# 5153

# %%
# Define the search query and the search period
query = "#fitnessmotivation"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
fitnessmotivation_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    fitnessmotivation_tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-30-ac79886b8c50> in <module>
#       5 fitnessmotivation_tweets = []
#       6 #for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
# ----> 7 for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
#       8     fitnessmotivation_tweets.append(tweet)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
len(fitnessmotivation_tweets)
# Out:
# 3771

# %%
# Define the search query and the search period
query = "#lowcal"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
lowcal_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    lowcal_tweets.append(tweet)

# %%
len(lowcal_tweets)
# Out:
# 21

# %%
# Define the search query and the search period
query = "#healthy"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
healthy_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    healthy_tweets.append(tweet)

# %%
len(healthy_tweets)
# Out:
# 210

# %%
# Define the search query and the search period
query = "#proana"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
proana_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    proana_tweets.append(tweet)

# %%
len(proana_tweets)
# Out:
# 254

# %%
# Define the search query and the search period
query = "#fitspo"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
fitspo_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    fitspo_tweets.append(tweet)

# %%
len(fitspo_tweets)
# Out:
# 225

# %%
# Define the search query and the search period
query = "#hipbones"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
hipbones_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    hipbones_tweets.append(tweet)

# %%
len(hipbones_tweets)
# Out:
# 1

# %%
# Define the search query and the search period
query = "#promia"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
promia_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    promia_tweets.append(tweet)

# %%
len(promia_tweets)
# Out:
# 46

# %%
# Define the search query and the search period
query = "#anorexia"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
anorexia_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    anorexia_tweets.append(tweet)

# %%
len(anorexia_tweets)
# Out:
# 495

# %%
# Define the search query and the search period
query = "#thinspiration"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
thinspiration_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    thinspiration_tweets.append(tweet)

# %%
len(thinspiration_tweets)
# Out:
# 6

# %%
# Define the search query and the search period
query = "#41DaysofStarvation"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
DaysofStarvation_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    DaysofStarvation_tweets.append(tweet)

# %%
len(DaysofStarvation_tweets)
# Out:
# 0

# %%
# Define the search query and the search period
query = "#bonespo"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
bonespo_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    bonespo_tweets.append(tweet)

# %%
len(bonespo_tweets)
# Out:
# 42

# %%
# Define the search query and the search period
query = "#thinspo"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
thinspo_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    thinspo_tweets.append(tweet)

# %%
len(thinspo_tweets)
# Out:
# 392

# %%
# Define the search query and the search period
query = "#weightloss"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
weightloss_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    weightloss_tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-74-82b3fdc22b28> in <module>
#       5 weightloss_tweets = []
#       6 #for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
# ----> 7 for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
#       8     weightloss_tweets.append(tweet)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
len(weightloss_tweets)
# Out:
# 3309

# %%
# Define the search query and the search period
query = "#bulimia"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
bulimia_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    bulimia_tweets.append(tweet)

# %%
len(bulimia_tweets)
# Out:
# 187

# %%
# Define the search query and the search period
query = "#edtwt"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
edtwt_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    anamia_tweets.append(tweet)

# %%
len(anamia_tweets)
# Out:
# 17

# %%
# Define the search query and the search period
query = "#edtwt"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
edtwt_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    edtwt_tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-85-efa617cb4bab> in <module>
#       5 edtwt_tweets = []
#       6 #for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
# ----> 7 for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
#       8     edtwt_tweets.append(tweet)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
len(edtwt_tweets)
# Out:
# 4255

# %%
# Define the search query and the search period
query = "#meanspo"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
meanspo_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    meanspo_tweets.append(tweet)

# %%
len(meanspo_tweets)
# Out:
# 209

# %%
# Define the search query and the search period
query = "#eatingdisorders"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
eatingdisorders_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    eatingdisorders_tweets.append(tweet)

# %%
len(eatingdisorders_tweets)
# Out:
# 1319

# %%
# Define the search query and the search period
query = "#dysmorphia"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
dysmorphia_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    dysmorphia_tweets.append(tweet)

# %%
len(dysmorphia_tweets)
# Out:
# 9

# %%
# Define the search query and the search period
query = "#mentalhealth"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
mentalhealth_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    mentalhealth_tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-114-6cf3df9579b9> in <module>
#       5 mentalhealth_tweets = []
#       6 #for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
# ----> 7 for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
#       8     mentalhealth_tweets.append(tweet)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
# ...

# %%
len(mentalhealth_tweets)
# Out:
# 6526

# %%
# Define the search query and the search period
query = "#EdTwitter"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
EdTwitter_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    EdTwitter_tweets.append(tweet)

# %%
len(EdTwitter_tweets)
# Out:
# 278

# %%
# Define the search query and the search period
query = "#depression"

# Use the API's search premium endpoint to retrieve all tweets containing the hashtag within the specified period
depression_tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q=query, since=start_date, until=end_date).items():
for tweet in tweepy.Cursor(api.search_tweets, q=query).items():
    depression_tweets.append(tweet)

# %%
len(depression_tweets)
# Out:
# 2867

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import json

for idx, tweet in enumerate(EdTwitter_tweets):
  with open('./drive/MyDrive/tweets/#EdTwitter_tweets/tweet_#EdTwitter_tweets_' + str(idx) + '.json', 'w') as f:
    json.dump(tweet._json, f, indent=4)
